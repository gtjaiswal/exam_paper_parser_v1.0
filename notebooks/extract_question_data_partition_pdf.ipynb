# %%
# !pip install unstructured
# Out:
# Collecting unstructured
#   Downloading unstructured-0.18.15-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: charset-normalizer in /opt/miniconda3/envs/exam_parser/lib/python3.11/site-packages (from unstructured) (3.4.4)
# Collecting filetype (from unstructured)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting python-magic (from unstructured)
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl.metadata (5.8 kB)
# Collecting lxml (from unstructured)
#   Downloading lxml-6.0.2-cp311-cp311-macosx_10_9_universal2.whl.metadata (3.6 kB)
# Collecting nltk (from unstructured)
#   Downloading nltk-3.9.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: requests in /opt/miniconda3/envs/exam_parser/lib/python3.11/site-packages (from unstructured) (2.32.5)
# Requirement already satisfied: beautifulsoup4 in /opt/miniconda3/envs/exam_parser/lib/python3.11/site-packages (from unstructured) (4.14.2)
# Collecting emoji (from unstructured)
#   Downloading emoji-2.15.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting dataclasses-json (from unstructured)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting python-iso639 (from unstructured)
#   Downloading python_iso639-2025.2.18-py3-none-any.whl.metadata (14 kB)
# Collecting langdetect (from unstructured)
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 30.0 MB/s  0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /opt/miniconda3/envs/exam_parser/lib/python3.11/site-packages (from unstructured) (2.3.4)
# Collecting rapidfuzz (from unstructured)
#   Downloading rapidfuzz-3.14.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting backoff (from unstructured)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: typing-extensions in /opt/miniconda3/envs/exam_parser/lib/python3.11/site-packages (from unstructured) (4.15.0)
# Collecting unstructured-client (from unstructured)
#   Downloading unstructured_client-0.42.3-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: wrapt in /opt/miniconda3/envs/exam_parser/lib/python3.11/site-packages (from unstructured) (2.0.0)
# Requirement already satisfied: tqdm in /opt/miniconda3/envs/exam_parser/lib/python3.11/site-packages (from unstructured) (4.67.1)
# Requirement already satisfied: psutil in /opt/miniconda3/envs/exam_parser/lib/python3.11/site-packages (from unstructured) (7.0.0)
# Collecting python-oxmsg (from unstructured)
#   Downloading python_oxmsg-0.0.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting html5lib (from unstructured)
#   Downloading html5lib-1.1-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: soupsieve>1.2 in /opt/miniconda3/envs/exam_parser/lib/python3.11/site-packages (from beautifulsoup4->unstructured) (2.8)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json->unstructured)
#   Downloading marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json->unstructured)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: packaging>=17.0 in /opt/miniconda3/envs/exam_parser/lib/python3.11/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->unstructured) (25.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json->unstructured)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: six>=1.9 in /opt/miniconda3/envs/exam_parser/lib/python3.11/site-packages (from html5lib->unstructured) (1.17.0)
# Requirement already satisfied: webencodings in /opt/miniconda3/envs/exam_parser/lib/python3.11/site-packages (from html5lib->unstructured) (0.5.1)
# Requirement already satisfied: click in /opt/miniconda3/envs/exam_parser/lib/python3.11/site-packages (from nltk->unstructured) (8.3.0)
# Collecting joblib (from nltk->unstructured)
#   Downloading joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting regex>=2021.8.3 (from nltk->unstructured)
#   Downloading regex-2025.10.23-cp311-cp311-macosx_11_0_arm64.whl.metadata (40 kB)
# Collecting olefile (from python-oxmsg->unstructured)
#   Downloading olefile-0.47-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: idna<4,>=2.5 in /opt/miniconda3/envs/exam_parser/lib/python3.11/site-packages (from requests->unstructured) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/miniconda3/envs/exam_parser/lib/python3.11/site-packages (from requests->unstructured) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/miniconda3/envs/exam_parser/lib/python3.11/site-packages (from requests->unstructured) (2025.10.5)
# Collecting aiofiles>=24.1.0 (from unstructured-client->unstructured)
#   Downloading aiofiles-25.1.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: cryptography>=3.1 in /opt/miniconda3/envs/exam_parser/lib/python3.11/site-packages (from unstructured-client->unstructured) (46.0.3)
# Requirement already satisfied: httpcore>=1.0.9 in /opt/miniconda3/envs/exam_parser/lib/python3.11/site-packages (from unstructured-client->unstructured) (1.0.9)
# Requirement already satisfied: httpx>=0.27.0 in /opt/miniconda3/envs/exam_parser/lib/python3.11/site-packages (from unstructured-client->unstructured) (0.28.1)
# Requirement already satisfied: pydantic>=2.11.2 in /opt/miniconda3/envs/exam_parser/lib/python3.11/site-packages (from unstructured-client->unstructured) (2.12.3)
# Requirement already satisfied: pypdf>=4.0 in /opt/miniconda3/envs/exam_parser/lib/python3.11/site-packages (from unstructured-client->unstructured) (6.1.3)
# Collecting requests-toolbelt>=1.0.0 (from unstructured-client->unstructured)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: cffi>=1.14 in /opt/miniconda3/envs/exam_parser/lib/python3.11/site-packages (from cryptography>=3.1->unstructured-client->unstructured) (2.0.0)
# Requirement already satisfied: pycparser in /opt/miniconda3/envs/exam_parser/lib/python3.11/site-packages (from cffi>=1.14->cryptography>=3.1->unstructured-client->unstructured) (2.22)
# Requirement already satisfied: h11>=0.16 in /opt/miniconda3/envs/exam_parser/lib/python3.11/site-packages (from httpcore>=1.0.9->unstructured-client->unstructured) (0.16.0)
# Requirement already satisfied: anyio in /opt/miniconda3/envs/exam_parser/lib/python3.11/site-packages (from httpx>=0.27.0->unstructured-client->unstructured) (4.11.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/miniconda3/envs/exam_parser/lib/python3.11/site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /opt/miniconda3/envs/exam_parser/lib/python3.11/site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/miniconda3/envs/exam_parser/lib/python3.11/site-packages (from pydantic>=2.11.2->unstructured-client->unstructured) (0.4.2)
# Requirement already satisfied: sniffio>=1.1 in /opt/miniconda3/envs/exam_parser/lib/python3.11/site-packages (from anyio->httpx>=0.27.0->unstructured-client->unstructured) (1.3.1)
# Downloading unstructured-0.18.15-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 81.8 MB/s  0:00:00
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading emoji-2.15.0-py3-none-any.whl (608 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 39.3 MB/s  0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
# Downloading lxml-6.0.2-cp311-cp311-macosx_10_9_universal2.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 79.1 MB/s  0:00:00
# Downloading nltk-3.9.2-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 65.8 MB/s  0:00:00
# Downloading regex-2025.10.23-cp311-cp311-macosx_11_0_arm64.whl (288 kB)
# Downloading joblib-1.5.2-py3-none-any.whl (308 kB)
# Downloading python_iso639-2025.2.18-py3-none-any.whl (167 kB)
# Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Downloading python_oxmsg-0.0.2-py3-none-any.whl (31 kB)
# Downloading olefile-0.47-py2.py3-none-any.whl (114 kB)
# Downloading rapidfuzz-3.14.1-cp311-cp311-macosx_11_0_arm64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 75.1 MB/s  0:00:00
# Downloading unstructured_client-0.42.3-py3-none-any.whl (207 kB)
# Downloading aiofiles-25.1.0-py3-none-any.whl (14 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Building wheels for collected packages: langdetect
#   DEPRECATION: Building 'langdetect' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'langdetect'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993332 sha256=f853c4437dedeced39a32dcddf786941953df6ad6300a28d8bcfd7abc41a1190
#   Stored in directory: /Users/garimajaiswal/Library/Caches/pip/wheels/0a/f2/b2/e5ca405801e05eb7c8ed5b3b4bcf1fcabcd6272c167640072e
# Successfully built langdetect
# Installing collected packages: filetype, regex, rapidfuzz, python-magic, python-iso639, olefile, mypy-extensions, marshmallow, lxml, langdetect, joblib, html5lib, emoji, backoff, aiofiles, typing-inspect, requests-toolbelt, python-oxmsg, nltk, unstructured-client, dataclasses-json, unstructured
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22/22 [unstructured] [unstructured]client]
# Successfully installed aiofiles-25.1.0 backoff-2.2.1 dataclasses-json-0.6.7 emoji-2.15.0 filetype-1.2.0 html5lib-1.1 joblib-1.5.2 langdetect-1.0.9 lxml-6.0.2 marshmallow-3.26.1 mypy-extensions-1.1.0 nltk-3.9.2 olefile-0.47 python-iso639-2025.2.18 python-magic-0.4.27 python-oxmsg-0.0.2 rapidfuzz-3.14.1 regex-2025.10.23 requests-toolbelt-1.0.0 typing-inspect-0.9.0 unstructured-0.18.15 unstructured-client-0.42.3

# %% [markdown]
# **Extract the data
# Extract the elements of the PDF that we will be able to use in the retrieval process. These elements can be: Text, Images, Tables, etc.**
